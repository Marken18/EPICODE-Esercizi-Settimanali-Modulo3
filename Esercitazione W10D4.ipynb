# %%
import os
import dotenv
import sqlalchemy
import pandas as pd

dotenv.load_dotenv(dotenv_path="cred.env", override=True)

username = os.getenv("username")
password = os.getenv("password")
host = os.getenv("host")
dbname = os.getenv("dbname")



connection_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
print(connection_string)

db_engine = sqlalchemy.create_engine(connection_string)
# Out:
# mysql+pymysql://studente_dapt:Ep1c0d3!!D4t4**4n4lys1s@epicode-data-pt-mysql.cvetyjye2qbl.eu-central-1.rds.amazonaws.com/AdventureWorksDW

# %%
#Esercizio 1) Dataframe Info
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
df.info
# Out:
# <bound method DataFrame.info of      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# ...

# %%
#Esercizio 1) Quanti dati ci sono? 606 righe per 36 colonne = 21.816
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
df.shape
# Out:
# (606, 36)

# %%
#Esercizio 1) Metadati
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
print("Indice:", df.index)
print("Colonne:", df.columns)
print("Forma:", df.shape)
print("Tipi di dati:\n", df.dtypes)
print("Info:\n", df.info())
# Out:
# Indice: RangeIndex(start=0, stop=606, step=1)
# Colonne: Index(['ProductKey', 'ProductAlternateKey', 'ProductSubcategoryKey',
#        'WeightUnitMeasureCode', 'SizeUnitMeasureCode', 'EnglishProductName',
#        'SpanishProductName', 'FrenchProductName', 'StandardCost',
#        'FinishedGoodsFlag', 'Color', 'SafetyStockLevel', 'ReorderPoint',
#        'ListPrice', 'Size', 'SizeRange', 'Weight', 'DaysToManufacture',
#        'ProductLine', 'DealerPrice', 'Class', 'Style', 'ModelName',
#        'LargePhoto', 'EnglishDescription', 'FrenchDescription',
#        'ChineseDescription', 'ArabicDescription', 'HebrewDescription',
#        'ThaiDescription', 'GermanDescription', 'JapaneseDescription',
#        'TurkishDescription', 'StartDate', 'EndDate', 'Status'],
#       dtype='object')
# Forma: (606, 36)
# Tipi di dati:
#  ProductKey                        int64
# ProductAlternateKey              object
# ProductSubcategoryKey           float64
# WeightUnitMeasureCode            object
# ...

# %%
#Esercizio 1) Stampa primo elemento con ILOC
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
primo_elemento = df.iloc[0,0]
print ("Il primo elemento è ", primo_elemento)
# Out:
# Il primo elemento è  1

# %%
#Esercizio 1) Stampa ultimo elemento con ILOC
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
ultimo_elemento = df.iloc[-1,-1]
print ("L'ultimo elemento è ", ultimo_elemento)
# Out:
# L'ultimo elemento è  Current

# %%
#Esercizio 1) Stampa 5 righe a caso
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
df.sample(5)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 254         255          FR-R38B-58                   14.0
# 510         511          FR-M63S-40                   12.0
# 392         393             FK-9939                   10.0
# 415         416             FW-T905                   17.0
# 358         359          BK-M68B-38                    1.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  \
# 254                    LB                  CM
# 510                    LB                  CM
# 392                  None                None
# 415                  None                None
# 358                    LB                  CM
#
#                    EnglishProductName                 SpanishProductName  \
# 254         LL Road Frame - Black, 58  Cuadro de carretera GB: negro, 58
# 510  ML Mountain Frame-W - Silver, 40
# 392                           HL Fork                       Horquilla GA
# ...

# %%
#Esercizio 1) Quali sono i colori disponibili
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
Colori_Disponibili = df["Color"].unique()
print ("I colori disponibili sono ",Colori_Disponibili)
# Out:
# I colori disponibili sono  ['NA' 'Black' 'Silver' 'Red' 'White' 'Blue' 'Multi' 'Yellow' 'Grey'
#  'Silver/Black']

# %%
#Esercizio 2) La media del peso dei prodotti
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
Media_Peso = df["Weight"].mean()
print ("La media del peso è ",Media_Peso)
# Out:
# La media del peso è  56.1932269503546

# %%
#Esercizio 2) Il peso più piccolo
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
Min_Peso = df["Weight"].min()
print ("Il peso più piccolo è  ",Min_Peso)
# Out:
# Il peso più piccolo è   2.12

# %%
#Esercizio 2) Il peso più pesante
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
Max_Peso = df["Weight"].max()
print ("Il peso più pesante è  ",Max_Peso)
# Out:
# Il peso più pesante è   1050.0

# %%
#Esercizio 2) Quanti prodotti pesano più di 100
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
Prodotti_100 = df[df["Weight"]>100].shape[0] #utilizzo shape per definire quante righe ci sono che hanno Weight più di 100
print ("Ci sono ",Prodotti_100, " prodotti che pesano più di 100")
# Out:
# Ci sono  28  prodotti che pesano più di 100

# %%
#Esercizio 2) La media del prezzo dei prodotti
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
Media_Prezzo = df["DealerPrice"].mean()
print ("La media del prezzo dei prodotti è ",Media_Prezzo)
# Out:
# La media del prezzo dei prodotti è  448.5970597468353

# %%
#Esercizio 2) I quantili dei prodotti
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
quartili = df["DealerPrice"].quantile([0.25, 0.5, 0.75])
print ("I quantili del prezzo dei prodotti sono ",quartili)
# Out:
# I quantili del prezzo dei prodotti sono  0.25     41.9940
# 0.50    218.4540
# 0.75    722.5949
# Name: DealerPrice, dtype: float64

# %%
#Esercizio 3) Prezzo medio per i prodotti di colore blu, è NAN, ovvero NON VALIDO
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
prezzo_medio_blu = df[df["Color"] == "Blue"]["DealerPrice"].mean()
print ("La media del prezzo dei prodotti blu è ",prezzo_medio_blu)
# Out:
# La media del prezzo dei prodotti blu è  516.0631785714286

# %%
#Esercizio 3) Prezzo medio per i prodotti di colore rosso o nero  è NAN, ovvero NON VALIDO
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)
prezzo_medio_rosso_nero = df[df["Color"].isin(["Red", "Black"])]["DealerPrice"].mean()
print ("La media del prezzo dei prodotti rosso o nero è ",prezzo_medio_rosso_nero )
# Out:
# La media del prezzo dei prodotti rosso o nero è  550.2481873684211

# %%
#Esercizio 3) Prezzo medio per i prodotti di taglia 42 oltre 10 di peso e argento  è NAN, ovvero NON VALIDO
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)

filtro_peso = df["Weight"] > 10
filtro_taglia = df["Size"] == "42"
filtro = filtro_peso & filtro_taglia 

df.loc[filtro, "DealerPrice"].max()
# Out:
# 2039.994

# %%
#Esercizio 3) nome prodotti  di produzione con le condizioni impostate
query = """SELECT * 
FROM dimproduct"""
df = pd.read_sql(query,db_engine)

filtro_taglia = df["Size"] == "42"
filtro_peso = df["Weight"] > 10
filtro_colore = df["Color"] == "Silver"
filtro = filtro_peso & filtro_taglia & filtro_colore

df.loc [filtro, "EnglishProductName"]
# Out:
# 344      Mountain-100 Silver, 42
# 353      Mountain-200 Silver, 42
# 354      Mountain-200 Silver, 42
# 588    Mountain-400-W Silver, 42
# 591      Mountain-500 Silver, 42
# Name: EnglishProductName, dtype: object

# %%
#Esercizio 3) mostra le ultime righe di dimproduct per le colonne selezionate e cerca un pattern particolare
df.tail(20).loc[:, ["StandardCost", "DealerPrice"]]
# Out:
#      StandardCost  DealerPrice
# 586        419.78      461.694
# 587        419.78      461.694
# 588        419.78      461.694
# 589        419.78      461.694
# 590        308.22      338.994
# 591        308.22      338.994
# 592        308.22      338.994
# 593        308.22      338.994
# 594        308.22      338.994
# 595        294.58      323.994
# 596        294.58      323.994
# 597        294.58      323.994
# 598        294.58      323.994
# 599        294.58      323.994
# 600         23.97       32.394
# 601         44.95       60.744
# 602         53.94       72.894
# 603        343.65      323.994
# 604        343.65      323.994
# 605        343.65      323.994

# %%
#Esercizio 4)
import pandas as pd
amazon = pd.read_csv("C:/Users/marko/OneDrive/Desktop/Esercizi e File Python/DataSet Beginner/datasets/beginner_datasets/amazon.csv") 
print(amazon)
# Out:
#                                               reviewText  Positive
# 0      This is a one of the best apps acording to a b...         1
# 1      This is a pretty good version of the game for ...         1
# 2      this is a really cool game. there are a bunch ...         1
# 3      This is a silly game and can be frustrating, b...         1
# 4      This is a terrific game on any pad. Hrs of fun...         1
# ...                                                  ...       ...
# 19995  this app is fricken stupid.it froze on the kin...         0
# 19996  Please add me!!!!! I need neighbors! Ginger101...         1
# 19997  love it!  this game. is awesome. wish it had m...         1
# 19998  I love love love this app on my side of fashio...         1
# 19999  This game is a rip off. Here is a list of thin...         0
#
# [20000 rows x 2 columns]

# %%
#Esercizio 4) identificare i tipi di dato 
amazon.dtypes
# Out:
# reviewText    object
# Positive       int64
# dtype: object

# %%
#Esercizio 4) identificare i valori unici di Positive
amazon["Positive"].unique()
# Out:
# array([1, 0])

# %%
#Esercizio 4) quanti dati ha il DF 
amazon.shape
# Out:
# (20000, 2)

# %%
#Esercizio 4) prendi 10 righe a caso
amazon.sample(10)
# Out:
#                                               reviewText  Positive
# 4167   works very well on inspire 4g. graphics are cu...         1
# 12152  Alarm Clock Xtreme Free is a great little tool...         1
# 11782  It was working for the first five months then ...         0
# 456    The game is great and different once I start p...         1
# 16181  ..... for my 6 yr old. This was never used, so...         0
# 3705   Fun, simple game! Worth the time to download, ...         1
# 5310   EVO 3d works fine. nice pictures and interface...         1
# 9949   This app has been exceptional at helping my 3r...         1
# 12625  actually  now that the maker of this app has f...         1
# 12335  Started to buy app on Market advertised for. 9...         1

# %%
#Esercizio 4) conta i valori che ci sono nella colonna "Positive"
amazon["Positive"].value_counts()
# Out:
# Positive
# 1    15233
# 0     4767
# Name: count, dtype: int64

# %%
#Esercizio 5) leggi il dataset di Diabetes

db = pd.read_csv("datasets/beginner_datasets/diabetes.csv")

# %%
#Esercizio 5) mostra il dataset originale
db
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 4                           0
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 4                                                  137
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# ...

# %%
#Esercizio 5) mostra i tipi di dati del dataset
db.dtypes
# Out:
# Number of times pregnant                                                      int64
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test      int64
# Diastolic blood pressure (mm Hg)                                              int64
# Triceps skin fold thickness (mm)                                              int64
# 2-Hour serum insulin (mu U/ml)                                                int64
# Body mass index (weight in kg/(height in m)^2)                              float64
# Diabetes pedigree function                                                  float64
# Age (years)                                                                   int64
# Class variable                                                                int64
# dtype: object

# %%
#Esercizio 5) mostra i totali di righe e colonne
db.shape
# Out:
# (768, 9)

# %%
#Esercizio 5) mostra i dati statistici del dataset
db.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# ...

# %%
#Esercizio 5) mostra i dati nelle fasce di età

filtro_eta_min = db["Age (years)"] >=20
filtro_eta_max = db["Age (years)"] <=29
filtro = filtro_eta_min & filtro_eta_max
media = db.loc[filtro, "Diastolic blood pressure (mm Hg)"].mean() 
print("La media della pressione sanguigna è", media)
# Out:
# La media della pressione sanguigna è 65.34848484848484

# %%
filtro_eta_min = db["Age (years)"] >=30
filtro_eta_max = db["Age (years)"] <=39
filtro = filtro_eta_min & filtro_eta_max
media = db.loc[filtro, "Diastolic blood pressure (mm Hg)"].mean() 
print("La media della pressione sanguigna è", media)
# Out:
# La media della pressione sanguigna è 69.66666666666667

# %%
filtro_eta_min = db["Age (years)"] >=40
filtro_eta_max = db["Age (years)"] <=50
filtro = filtro_eta_min & filtro_eta_max
media = db.loc[filtro, "Diastolic blood pressure (mm Hg)"].mean() 
print("La media della pressione sanguigna è", media)
# Out:
# La media della pressione sanguigna è 74.21428571428571

# %%
#Esercizio 6) leggi il dataset insurance
ins = pd.read_csv("datasets/beginner_datasets/insurance.csv")

# %%
#Esercizio 6) mostra il dataset
ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#Esercizio 6) tipi di dati nel dataset 
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#Esercizio 6) dati statistici del dataframe
ins.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#Esercizio 6) elenco delle colonne del dataset e mostra i dati statistici delle varie colonne
ins.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
ins["charges"].describe()
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %%
ins["region"].describe()
# Out:
# count          1338
# unique            4
# top       southeast
# freq            364
# Name: region, dtype: object

# %%
ins["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
ins["sex"].describe()
# Out:
# count     1338
# unique       2
# top       male
# freq       676
# Name: sex, dtype: object

# %%
ins["smoker"].describe()
# Out:
# count     1338
# unique       2
# top         no
# freq      1064
# Name: smoker, dtype: object

# %%
ins["bmi"].describe()
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
#Esercizio 7) #leggiamo il dataset di pokemon
poke = pd.read_csv("datasets/beginner_datasets/pokemon.csv")

# %%
#Esercizio 7) mostriamo l'antemprima del dataset e i suoi vari dati
poke
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
poke.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
poke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
poke.shape
# Out:
# (800, 13)

# %%
poke.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#Esercizio 6) l'indice e la prima colonna del dataset non combaciano, la prima colonna riguarda il numero del
#pokemon e non la posizione, per essere precisi andrebbe sempre seguita la posizione dell'indice

# %%
#Esercizio 6) settato la colonna "#" come indice
poke.set_index("#")
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
poke_legg=poke["Name"].isin(poke["Legendary"])
print ("I pokemon leggendari sono",poke_legg)
# Out:
# I pokemon leggendari sono 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Name, Length: 800, dtype: bool

# %%
#Esercizio 6) Mostra i pokemon leggendari
leggendari = poke[poke['Legendary'] == True]
poke_legg = leggendari["Name"]
print("I Pokémon leggendari sono:", poke_legg)
# Out:
# I Pokémon leggendari sono: 156               Articuno
# 157                 Zapdos
# 158                Moltres
# 162                 Mewtwo
# 163    MewtwoMega Mewtwo X
#               ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
# Name: Name, Length: 65, dtype: object

# %%
#Esercizio 6) mostra i pokemon leggendari di tipo erba
grass_leggendari = poke[(poke['Type 1'] == 'Grass') & (poke['Legendary'] == True)]
print("Leggendari di tipo 1 Grass:", grass_leggendari)
# Out:
# Leggendari di tipo 1 Grass:        #               Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 550  492  ShayminLand Forme  Grass       NaN    600  100     100      100
# 551  492   ShayminSky Forme  Grass    Flying    600  100     103       75
# 701  640           Virizion  Grass  Fighting    580   91      90       72
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 550      100      100    100           4       True
# 551      120       75    127           4       True
# 701       90      129    108           5       True

# %%
#Mostra i pokemon leggendari di tipo ghiaccio o fuoco 
ice_fire_leggendari = poke[(poke['Type 1'].isin(['Ice', 'Fire'])) & (poke['Legendary'] == True)]
print("Leggendari di tipo 1 Ice o Fire:", ice_fire_leggendari)
# Out:
# Leggendari di tipo 1 Ice o Fire:        #       Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 156  144   Articuno    Ice  Flying    580   90      85      100       95
# 158  146    Moltres   Fire  Flying    580   90     100       90      125
# 263  244      Entei   Fire     NaN    580  115     115       85       90
# 270  250      Ho-oh   Fire  Flying    680  106     130       90      110
# 415  378     Regice    Ice     NaN    580   80      50      100      100
# 542  485    Heatran   Fire   Steel    600   91      90      106      130
# 799  721  Volcanion   Fire   Water    600   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 156      125     85           1       True
# 158       85     90           1       True
# 263       75    100           2       True
# 270      154     90           2       True
# 415      200     50           3       True
# 542      106     77           4       True
# 799       90     70           6       True

# %%
#Esercizio 6) trasformiamo il nome nell'indice
poke.set_index("Name")
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                1    Grass  Poison    318  45      49       49
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
#Esercizio 6) i pokemon della prima generazione con HP tra 50 e 60
prima_gen = poke[(poke["Generation"] == 1) & (poke["Attack"] > 50) & (poke["HP"] < 60)]
print("Pokémon della prima generazione con Attack > 50 e HP < 60:", prima_gen)
# Out:
# Pokémon della prima generazione con Attack > 50 e HP < 60:        #        Name    Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 4      4  Charmander      Fire     NaN    309  39      52       43       60
# 5      5  Charmeleon      Fire     NaN    405  58      64       58       80
# 10     8   Wartortle     Water     NaN    405  59      63       80       65
# 24    19     Rattata    Normal     NaN    253  30      56       35       25
# 25    20    Raticate    Normal     NaN    413  55      81       60       50
# 26    21     Spearow    Normal  Flying    262  40      60       30       31
# 28    23       Ekans    Poison     NaN    288  35      60       44       40
# 30    25     Pikachu  Electric     NaN    320  35      55       40       50
# 32    27   Sandshrew    Ground     NaN    300  50      75       85       20
# 37    32    Nidoran♂    Poison     NaN    273  46      57       40       40
# 51    46       Paras       Bug   Grass    285  35      70       55       45
# ...
